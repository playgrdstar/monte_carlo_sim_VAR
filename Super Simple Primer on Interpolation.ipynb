# %% [markdown]
# ### Super Simple Primer on Interpolation###

# %% [markdown]
# There are always gaps in data, so interpolation is essential for data analysis. In finance, interpolation is especially useful when we are dealing with time series data.

# %% [markdown]
# To get acquainted with interpolation, let's do a super simple toy example.

# %%
# Let's create a simple random time series 
import pandas as pd
import numpy as np

timerange = pd.date_range('1/1/2016', periods=252)
mean = 1.2
std = 0.3

t_series = pd.DataFrame(np.random.normal(mean, std ,len(timerange)), 
                        index=timerange, columns=['Prices'])

# %%
t_series.head(3)
# Out:
#               Prices
# 2016-01-01  1.413515
# 2016-01-02  1.394857
# 2016-01-03  1.360298

# %% [markdown]
# Let's randomly insert 50 gaps in the time series

# %%
t_series['Prices_Gapped'] = t_series['Prices']
t_series.loc[np.random.choice(t_series.index, 80), 'Prices_Gapped'] = np.nan

# %%
t_series.head(20)
# Out:
#               Prices  Prices_Gapped
# 2016-01-01  1.413515       1.413515
# 2016-01-02  1.394857       1.394857
# 2016-01-03  1.360298       1.360298
# 2016-01-04  1.290587            NaN
# 2016-01-05  1.752690            NaN
# 2016-01-06  1.451516       1.451516
# 2016-01-07  0.492146       0.492146
# 2016-01-08  1.796194       1.796194
# 2016-01-09  1.026254       1.026254
# 2016-01-10  1.106907       1.106907
# 2016-01-11  1.229492       1.229492
# 2016-01-12  1.156451       1.156451
# 2016-01-13  1.504587       1.504587
# 2016-01-14  1.393259            NaN
# 2016-01-15  1.485459            NaN
# 2016-01-16  1.465053       1.465053
# 2016-01-17  1.277476       1.277476
# 2016-01-18  1.297574            NaN
# 2016-01-19  1.505438            NaN
# 2016-01-20  1.662757       1.662757

# %% [markdown]
# All it takes is one line to interpolate the data

# %%
t_series['Prices_Filled']=t_series['Prices_Gapped'].interpolate(method='linear')

# %%
t_series.head(20)
# Out:
#               Prices  Prices_Gapped  Prices_Filled
# 2016-01-01  1.413515       1.413515       1.413515
# 2016-01-02  1.394857       1.394857       1.394857
# 2016-01-03  1.360298       1.360298       1.360298
# 2016-01-04  1.290587            NaN       1.390704
# 2016-01-05  1.752690            NaN       1.421110
# 2016-01-06  1.451516       1.451516       1.451516
# 2016-01-07  0.492146       0.492146       0.492146
# 2016-01-08  1.796194       1.796194       1.796194
# 2016-01-09  1.026254       1.026254       1.026254
# 2016-01-10  1.106907       1.106907       1.106907
# 2016-01-11  1.229492       1.229492       1.229492
# 2016-01-12  1.156451       1.156451       1.156451
# 2016-01-13  1.504587       1.504587       1.504587
# 2016-01-14  1.393259            NaN       1.491409
# 2016-01-15  1.485459            NaN       1.478231
# 2016-01-16  1.465053       1.465053       1.465053
# 2016-01-17  1.277476       1.277476       1.277476
# 2016-01-18  1.297574            NaN       1.405903
# 2016-01-19  1.505438            NaN       1.534330
# 2016-01-20  1.662757       1.662757       1.662757

# %% [markdown]
# Linear interpolation might not get what we want. You can see that the filled prices are not the same as the original time series. Other interpolation methods are available.

# %%
t_series['Prices_Filled_Cubic']=t_series['Prices_Gapped'].interpolate(method='cubic')

# %%
t_series['Prices_Filled_Poly']=t_series['Prices_Gapped'].interpolate(method='polynomial', order=2)

# %%
t_series.head(20)
# Out:
#               Prices  Prices_Gapped  Prices_Filled  Prices_Filled_Cubic  \
# 2016-01-01  1.413515       1.413515       1.413515             1.413515
# 2016-01-02  1.394857       1.394857       1.394857             1.394857
# 2016-01-03  1.360298       1.360298       1.360298             1.360298
# 2016-01-04  1.290587            NaN       1.390704             1.745530
# 2016-01-05  1.752690            NaN       1.421110             2.029394
# 2016-01-06  1.451516       1.451516       1.451516             1.451516
# 2016-01-07  0.492146       0.492146       0.492146             0.492146
# 2016-01-08  1.796194       1.796194       1.796194             1.796194
# 2016-01-09  1.026254       1.026254       1.026254             1.026254
# 2016-01-10  1.106907       1.106907       1.106907             1.106907
# 2016-01-11  1.229492       1.229492       1.229492             1.229492
# 2016-01-12  1.156451       1.156451       1.156451             1.156451
# 2016-01-13  1.504587       1.504587       1.504587             1.504587
# 2016-01-14  1.393259            NaN       1.491409             1.710804
# 2016-01-15  1.485459            NaN       1.478231             1.664292
# 2016-01-16  1.465053       1.465053       1.465053             1.465053
# 2016-01-17  1.277476       1.277476       1.277476             1.277476
# 2016-01-18  1.297574            NaN       1.405903             1.390215
# 2016-01-19  1.505438            NaN       1.534330             1.623124
# 2016-01-20  1.662757       1.662757       1.662757             1.662757
#
#             Prices_Filled_Poly
# 2016-01-01            1.413515
# 2016-01-02            1.394857
# 2016-01-03            1.360298
# 2016-01-04            1.591244
# 2016-01-05            1.963615
# 2016-01-06            1.451516
# 2016-01-07            0.492146
# 2016-01-08            1.796194
# 2016-01-09            1.026254
# 2016-01-10            1.106907
# 2016-01-11            1.229492
# 2016-01-12            1.156451
# 2016-01-13            1.504587
# 2016-01-14            1.692399
# 2016-01-15            1.627754
# 2016-01-16            1.465053
# 2016-01-17            1.277476
# 2016-01-18            1.349705
# 2016-01-19            1.645500
# 2016-01-20            1.662757

# %% [markdown]
# Other than cubic and polynomial, other interpolation methods are available. See here - https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.interpolate.html
